# %%
import pandas as pd

df = pd.read_csv("../Data/prediction_idealista.csv")

# %%
df
# Out:
#       ad_typology_Value  ad_price  ad_area     ad_district  \
# 0                  home    315000       61  Sants-Montjuïc
# 1                  home    450000      166    Ciutat Vella
# 2                  home    179000       58    Ciutat Vella
# 3                  home    150000       30        Eixample
# 4                  home    120000       62  Sants-Montjuïc
# ...                 ...       ...      ...             ...
# 33548              home    350000       83      Sant Martí
# 33549              home    214000       53      Sant Martí
# 33550              home    128000       48      Sant Martí
# 33551              home    269000       90      Sant Martí
# 33552              home    340000      106      Sant Martí
#
#                     ad_builttype_Value  ad_roomnumber  ad_bathnumber  \
# 0      second hand / in good condition              2              1
# 1         second hand / to be restored              7              2
# ...
