# %%
#Libraries:

import pandas as pd
import numpy as np
import pprint

# %%
df = pd.read_csv("../Data/dataset_idealista.csv")

# %%
df.sample(10)
# Out:
#            ad_id ad_state_Value ad_operation_Value ad_typology_Value  \
# 11678  100830361    inactive ad               sale              home
# 14827  100729796    inactive ad               sale              home
# 29304  100548096    inactive ad               sale              home
# 31139  101996742    inactive ad               sale              home
# 11459  101077642    inactive ad               sale              home
# 31887  102798736    inactive ad               sale              home
# 26247  103354321    inactive ad               sale              home
# 22396  103214537      active ad               sale              home
# 8851   100972679    inactive ad               sale              home
# 17220  103314070      active ad               sale              home
#
#        ad_price  ad_area ad_activationdate ad_deactivationdate  ad_latitude  \
# 11678     94000     53.0        2023-03-16          2023-04-25    41.416754
# ...

# %%
df.dtypes
# Out:
# ad_id                      int64
# ad_state_Value            object
# ad_operation_Value        object
# ad_typology_Value         object
# ad_price                   int64
# ad_area                  float64
# ad_activationdate         object
# ad_deactivationdate       object
# ad_latitude              float64
# ad_longitude             float64
# ad_town                   object
# ad_district               object
# ad_neighbourhood          object
# ad_builttype_Value        object
# ad_roomnumber              int64
# ad_bathnumber              int64
# ad_haslift               float64
# ad_hasswimmingpool       float64
# ad_hasheating            float64
# ad_hasterrace            float64
# ad_hasparkingspace       float64
# ad_hasairconditioning    float64
# ad_hasgarden             float64
# dtype: object

# %%
num_rows, num_columns = df.shape

print("Number of Rows:", num_rows)
print("Number of Columns:", num_columns)
# Out:
# Number of Rows: 39711
# Number of Columns: 23

# %%
columns_with_nulls = df.columns[df.isnull().any()]
null_counts = df[columns_with_nulls].isnull().sum().sort_values(ascending=False)

print("Columns with the most null values:")
print(null_counts)
# Out:
# Columns with the most null values:
# ad_hasparkingspace       28540
# ad_hasswimmingpool       26133
# ad_hasgarden             26096
# ad_hasheating            20918
# ad_hasterrace            19844
# ad_hasairconditioning    15353
# ad_deactivationdate       5865
# ad_haslift                1228
# dtype: int64

# %%
df.describe()
# Out:
#               ad_id      ad_price        ad_area   ad_latitude  ad_longitude  \
# count  3.971100e+04  3.971100e+04   39711.000000  39711.000000  39711.000000
# mean   1.011780e+08  3.552958e+05     115.028016     41.402614      2.166602
# std    3.354026e+06  3.634011e+05    4993.007203      0.022492      0.022775
# min    5.265630e+05  8.000000e+02      11.000000     41.331251      2.079461
# 25%    1.006082e+08  1.980000e+05      64.000000     41.383098      2.148911
# 50%    1.014625e+08  2.800000e+05      79.000000     41.402178      2.168026
# 75%    1.024586e+08  4.000000e+05     100.000000     41.418127      2.181780
# max    1.033606e+08  2.500000e+07  995000.000000     41.467973      2.222086
#
#        ad_roomnumber  ad_bathnumber    ad_haslift  ad_hasswimmingpool  \
# count   39711.000000   39711.000000  38483.000000        13578.000000
# mean        2.843167       1.440382      0.746875            0.086095
# ...

# %%
df['ad_operation_Value'].unique().sum()
# Out:
# 'sale'

# %%
df['ad_typology_Value'].unique().sum()
# Out:
# 'homechalet'

# %%
df['ad_town'].unique().sum()
# Out:
# 'Barcelona'

# %%
df['ad_builttype_Value'].unique().sum()
# Out:
# 'second hand / in good conditionsecond hand / to be restorednew development'

# %%
df[['ad_builttype_Value']].sample(10)
# Out:
#                     ad_builttype_Value
# 39336  second hand / in good condition
# 18147  second hand / in good condition
# 16653  second hand / in good condition
# 30602  second hand / in good condition
# 27919     second hand / to be restored
# 32640     second hand / to be restored
# 262    second hand / in good condition
# 23560  second hand / in good condition
# 27282  second hand / in good condition
# 31124  second hand / in good condition

# %%
sorted_df = df[['ad_price']].sort_values(by='ad_price', ascending=False)

# %%
sorted_df.head(20)
# Out:
#        ad_price
# 25289  25000000
# 31441  17000000
# 37300  15500000
# 5687   14000000
# 25427  13800000
# 17136  12900000
# 4712   10000000
# 29327  10000000
# 33367   9500000
# 33536   8350000
# 36245   8000000
# 25859   7000000
# 29138   6800000
# 5119    5800000
# 25290   5500000
# 39709   5500000
# 31189   5490000
# 5120    5200000
# 39587   5000000
# 17284   4750000

# %%
"""
We can observe many null values but thanks to our data provided we know that many of those null values aren't actual null values replacable one.
There are also some unnecessary columns that need to me removed 
"""
